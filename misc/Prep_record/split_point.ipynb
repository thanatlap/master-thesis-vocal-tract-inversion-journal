# %% [markdown]
# # Split Point in Speech Signal
# - Created 8 Apr 2020

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from os.path import join
import librosa

import shutil 
import pickle
from IPython.display import Audio
import scipy

# %%
def import_data(data_path):
    
    with open(join(data_path,'sound_set.txt'), 'r') as f:
        data = np.array(f.read().split(','))
    audio_paths = [join(data_path,file+'.wav') for file in data]

    audio_data = np.array([ librosa.load(file, sr=SAMPLE)[0] for file in audio_paths ])
    return audio_data

# %%
FOLDER = 'd_record_aj'
# FOLDER = 'd_record_mom'
# FOLDER = 'd_record_pat'
# FOLDER = 'd_record_kring'
# FOLDER = 'd_record_sorn'
# FOLDER = 'd_record_in'
# FOLDER = 'd_record_su'
# FOLDER = 'd_record_sorn_sis'
# FOLDER = 'd_record_gam'
# FOLDER = 'd_record_plooktan'
# FOLDER = 'd_record_blank'

# %%
PARENT_PATH = '../../data/d_records/'
DATA_PATH = join(PARENT_PATH,FOLDER)
SAMPLE = 16000

FORMANT_PATH = 'formant_actual'

# %%
audio = import_data(DATA_PATH)

# %%
S = 12
plt.plot(audio[S])
plt.show()

# %%
data = pd.read_csv('formant_actual/{}/actual_format_0.txt'.format(FOLDER), sep=",", na_values='--undefined--')
data.head()
# Out:
#    time          f1           f2           f3
# 0  0.01         NaN          NaN          NaN
# 1  0.02         NaN          NaN          NaN
# 2  0.03  775.795045  1443.848922  3152.595517
# 3  0.04  866.909276  1471.137723  3304.943376
# 4  0.05  887.561332  1491.391078  2643.721702

# %%
LENGTH = 1.2

for i in range(81):    
    data = pd.read_csv('formant_actual/{}/actual_format_{}.txt'.format(FOLDER, i), sep=",", na_values='--undefined--')
#     fig, ax = plt.subplots(1,2,figsize = (35,3))
#     ax[0].set_title('[F1] Sound {}'.format(i))
#     ax[0].plot(data['time'], data['f1'])
#     ax[0].set_xticks(np.arange(0.0, LENGTH+0.001, 0.05))
#     ax[0].set_yticks(np.arange(100, 1650+0.001, 200))
#     ax[0].grid()

#     ax[1].set_title('[F2] Sound {}'.format(i))
#     ax[1].plot(data['time'], data['f2'])
#     ax[1].set_xticks(np.arange(0.0, LENGTH+0.001, 0.05))
#     ax[1].set_yticks(np.arange(1000, 3000+0.001, 500))
#     ax[1].grid()

    fig, ax = plt.subplots(1,1,figsize = (20,5))
    ax.set_title('[F1, F2] Sound {}'.format(i))
    ax.plot(data['time'], data['f1'], color='blue')
    ax.plot(data['time'], data['f2'], color='red')
    ax.set_xticks(np.arange(0.0, LENGTH+0.001, 0.05))
    ax.set_yticks(np.arange(100, 3000+0.001, 200))
    ax.grid()

    plt.show()
