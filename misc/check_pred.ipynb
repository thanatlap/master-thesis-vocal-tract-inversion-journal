# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pred = np.load('y_pred.npy')
target = np.load('../data/d_dataset_4/prep_exp10_l4/training_subsets.npz')['y_test']
target = np.delete(target,[2,8,15,16,21,22,23]  , axis=1)

# %%
pred[1]
# Out:
# array([-0.2964631 , -0.00449393, -0.28280446, -0.0950635 ,  0.09595516,
#        -0.06790484,  0.16427845, -0.07865921, -0.5240233 ,  0.14548478,
#        -0.03379398, -0.16033955, -0.12843211, -0.24416633,  0.00750462,
#         0.3453305 ,  0.11254707], dtype=float32)

# %%
pred[0]
# Out:
# array([-0.65525186,  0.5926838 , -0.2046006 , -0.6960607 ,  0.7038396 ,
#         0.32851285,  0.38045904,  0.15050414, -0.8138855 ,  0.3976446 ,
#        -0.42047402, -0.1139586 , -0.12689705, -0.24561858,  0.0555016 ,
#         0.47377527, -0.07409848], dtype=float32)

# %%
target[2]
# Out:
# array([-1.19856781,  1.6802907 , -4.71159629, -3.05301774,  1.21579443,
#         1.62106526, -1.11462926,  0.67116346,         nan,  0.73492931,
#         0.09345141, -0.60701456,  0.29922857,  2.02582651, -1.6906351 ,
#        -4.8262347 ,  1.01112817,  1.34104699,  0.34817312, -1.12921431,
#        -0.27814495, -0.23310375, -0.23278712, -0.23383206])

# %%
target[1]
# Out:
# array([ 0.45947512, -0.38381869,  0.53661644, -1.81455639,  0.29046985,
#        -0.49553343,  0.40445679, -0.84170315,         nan, -0.55054423,
#         0.10262985, -1.8623841 ,  0.03120496, -1.02473268, -0.14801781,
#         0.45137882, -0.44979542, -0.00766411, -1.40837128, -0.97341528,
#        -0.90989319, -0.23310375, -0.23278712, -0.23383206])

# %%
target_feat = np.load('../data/d_dataset_4/prep_exp10_l4/training_subsets.npz')['X_test']

# %%
target_feat[0]
# Out:
# array([[-1.23042162, -0.96888202,  0.32910973, ...,  0.24395792,
#         -1.04821696, -1.83119052],
#        [-1.24380134, -0.94865255,  0.53740028, ...,  0.24395792,
#         -1.04821696, -1.83119052],
#        [-1.17955147, -0.82426979,  0.68219525, ...,  0.24395792,
#         -1.04821696, -1.83119052],
#        ...,
#        [ 0.12707679,  0.94397145, -0.77668768, ...,  0.23853174,
#         -1.26509846,  1.92507694],
#        [ 0.22735408,  0.77624639, -0.95228915, ...,  0.23853174,
#         -1.26509846,  1.92507694],
#        [ 0.63724006,  0.14316844, -0.39066692, ...,  0.23853174,
#         -1.26509846,  1.92507694]])

# %%
target_feat[1]
# Out:
# array([[-0.93350619, -0.96888202,  0.32910973, ..., -0.74937155,
#         -0.43274657, -0.2616674 ],
#        [-0.94077937, -0.97660867,  0.43741469, ..., -0.74937155,
#         -0.43274657, -0.2616674 ],
#        [-0.88161678, -0.9307821 ,  0.48123308, ..., -0.74937155,
#         -0.43274657, -0.2616674 ],
#        ...,
#        [ 0.115728  ,  0.4149106 , -0.28468115, ...,  0.85190787,
#          1.36711578,  1.08225131],
#        [ 0.11611131,  0.43926117, -0.19772855, ...,  0.85190787,
#          1.36711578,  1.08225131],
#        [ 0.07037011,  0.5706048 , -0.08629982, ...,  0.85190787,
#          1.36711578,  1.08225131]])

# %%
fig, axs = plt.subplots(3,6, figsize=(20,10))

i = 0
for row in axs:
    for col in row:
        col.hist(target[:,i])
        i += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-7ae8ba882d7e> in <module>
#       4 for row in axs:
#       5     for col in row:
# ----> 6         col.hist(target[:,i])
#       7         i += 1
#       8
#
# IndexError: index 17 is out of bounds for axis 1 with size 17

# %%
fig, axs = plt.subplots(3,6, figsize=(20,10))

i = 0
for row in axs:
    for col in row:
        col.hist(pred[:,i])
        i += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-200eb0e63f91> in <module>
#       4 for row in axs:
#       5     for col in row:
# ----> 6         col.hist(pred[:,i])
#       7         i += 1
#       8
#
# IndexError: index 17 is out of bounds for axis 1 with size 17
