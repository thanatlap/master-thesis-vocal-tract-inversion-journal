# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pred = np.load('y_pred.npy')
target = np.load('../data/d_dataset_4/prep_exp10_l4/training_subsets.npz')['y_test']
target = np.delete(target,[2,8,15,16,21,22,23]  , axis=1)

# %%
ITEM = 3
print(pred[ITEM])
print(target[ITEM])
# Out:
# [ 0.16091666  0.45605513 -0.16927747 -0.51997     0.27714577  0.30911002
#  -0.2878856   0.5477756   0.5417383  -0.35338634 -0.1354642  -0.27733907
#   0.4397485  -0.03392736 -0.21768342 -0.36780313 -0.60553294]
# [ 0.64408422  0.80912865 -0.14014401 -1.12407937 -0.23871417 -0.18349945
#   1.5039564  -0.0482463   0.69055124  0.92758387 -0.33197094  0.77621322
#   0.41113285 -0.75601097 -0.65788857 -0.6340956  -2.71410089]

# %%
fig, axs = plt.subplots(3,6, figsize=(20,10))

i = 0
for row in axs:
    for col in row:
        col.hist(target[:,i])
        i += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-7ae8ba882d7e> in <module>
#       4 for row in axs:
#       5     for col in row:
# ----> 6         col.hist(target[:,i])
#       7         i += 1
#       8
#
# IndexError: index 17 is out of bounds for axis 1 with size 17

# %%
fig, axs = plt.subplots(3,6, figsize=(20,10))

i = 0
for row in axs:
    for col in row:
        col.hist(pred[:,i])
        i += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-200eb0e63f91> in <module>
#       4 for row in axs:
#       5     for col in row:
# ----> 6         col.hist(pred[:,i])
#       7         i += 1
#       8
#
# IndexError: index 17 is out of bounds for axis 1 with size 17
